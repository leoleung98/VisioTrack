# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# !pip install transformers opencv-python-headless ultralytics jupyter
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...
#      ---------------------------------------- 0.0/4.1 MB ? eta -:--:--
#      ---------------------------------------- 4.1/4.1 MB 35.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/2.4 GB ? eta -:--:--
#      ---------------------------------------- 0.0/2.4 GB 76.3 MB/s eta 0:00:32
#      ---------------------------------------- 0.0/2.4 GB 55.3 MB/s eta 0:00:44
#      ---------------------------------------- 0.0/2.4 GB 41.9 MB/s eta 0:00:58
#       --------------------------------------- 0.0/2.4 GB 42.1 MB/s eta 0:00:58
#       --------------------------------------- 0.0/2.4 GB 39.4 MB/s eta 0:01:02
#       --------------------------------------- 0.0/2.4 GB 32.0 MB/s eta 0:01:16
#       --------------------------------------- 0.0/2.4 GB 28.5 MB/s eta 0:01:25
#       --------------------------------------- 0.1/2.4 GB 32.6 MB/s eta 0:01:14
# ...

# %%
# Out:
# PyTorch version: 2.4.1+cu121
# CUDA available: True
# CUDA version: 12.1
# CUDA is available! PyTorch is using GPU: NVIDIA GeForce RTX 3070
# Number of available GPUs: 1
# Current GPU device index: 0
